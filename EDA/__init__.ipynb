# %% [markdown]
# ## Exploratory Data Analysis
#
# EDA involves using a variety of tools (statistically, observatory, etc )
# over a dataset to describe it better
#
# ### Working with the Iris data set
# 1. A very popular dataset wo begin with
# 2. Contains data regarding petal and sepal properties of
#  3 species of Iris flower
# 3. [Link to the data set wikipedia page](https://en.wikipedia.org/wiki/Iris_flower_data_set)
# 4. [Link to the data set](https://archive.ics.uci.edu/ml/datasets/iris)
#
# **Objective :** Classify a flower into one of the 3 species (Classification)
#
# Sepal vs petal :
#
# ![](petal_sepal.jpg)
#
# Note
#
# 1. Rows in dataset can be termed as record or datapoint/ vector (n dimensional array)
# 2. Labels are also called independent variables, output variable, class, class label, response label
# 3. Features are also known as variable, input/ dependent variable
# 4. 1-D vectors are called scalar

# %%
# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Iris dataset
# The last column is the label for the flower with given features
# We need to classify a flower into one of the three labels given these four features
df = pd.read_csv("iris.data")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 10            5.4          3.7           1.5          0.2     Iris-setosa
# 11            4.8          3.4           1.6          0.2     Iris-setosa
# ...

# %%
# Columns in the dataset
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# Find the no of datapoints given for each class
# Here each class has equal number of datapoint
# Such a dataset is called balanced while rest are known as imbalanced datasets
df.species.value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: species, dtype: int64
